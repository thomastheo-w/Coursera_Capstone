# %% [markdown]
# ## Background
# ### Yogyakarta is arguably the cultural capital city of Indonesia, particularly Javanese culture. The city and province, are still ruled by a monarchy, an anomaly in the 21th century. Yogyakarta is home for plethora of incredible buildings, landmarks, and monuments. Borobudur temple, one of the Seven Wonders are located in the nearby city of Magelang; other famous places also includes, but not limited to: Prambanan temple, and Kraton Yogyakarta.
#
# ### The city are also famous for its culinary heritage that's distinct from the other region, with food such as 'Gudeg', 'Bakpia', et cetera. One of the most famous food in from the city is called 'Bakpia'. Bakpia is a pastry filled with numerous filings, the classic and the most famous filling are green peas (mung beans), but other flavor and brand has innovate and produce numerous other fillings as well, e.g. chocolate, cheese, even durian. Bakpia is usually bought as a souvenirs from the city.

# %% [markdown]
# ## Objective
#
# ### The research objectives are:
# ### 1) Find bakpia location in Yogyakarta;
# ### 2) Explore trending venues in Yogyakarta so it can help tourist prioritize their trips.

# %% [markdown]
# ### *Data acquisition*
#
# #### a. Yogyakarta coordinates that’s obtained from geopy.geocoders and Nominatim;
# #### b. Foursquare API using client id and client secret to explore trending venues in Yogyakarta and to find bakpia store in Yogyakarta. Foursquare API website: https://developer.foursquare.com/ ;
# #### c. analyze data got through Foursquare.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     scikit-learn-0.20.1        |   py36h22eb022_0         5.7 MB
#     liblapack-3.8.0            |      11_openblas          10 KB  conda-forge
#     scipy-1.3.2                |   py36h921218d_0        18.0 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     libopenblas-0.3.6          |       h5a2b251_2         7.7 MB
#     liblapacke-3.8.0           |      11_openblas          10 KB  conda-forge
#     numpy-1.17.3               |   py36h95a1406_0         5.2 MB  conda-forge
#     libcblas-3.8.0             |      11_openblas          10 KB  conda-forge
#     libblas-3.8.0              |      11_openblas          10 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     blas-2.11                  |         openblas          10 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        36.9 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0                              conda-forge
#     geopy:         1.20.0-py_0                            conda-forge
#     libblas:       3.8.0-11_openblas                      conda-forge
#     libcblas:      3.8.0-11_openblas                      conda-forge
#     liblapack:     3.8.0-11_openblas                      conda-forge
#     liblapacke:    3.8.0-11_openblas                      conda-forge
#     libopenblas:   0.3.6-h5a2b251_2
#
# The following packages will be UPDATED:
#
#     blas:          1.1-openblas                           conda-forge --> 2.11-openblas         conda-forge
#     certifi:       2019.9.11-py36_0                       conda-forge --> 2019.11.28-py36_0     conda-forge
#     numpy:         1.16.2-py36_blas_openblash1522bff_0    conda-forge [blas_openblas] --> 1.17.3-py36h95a1406_0 conda-forge
#     scipy:         1.2.1-py36_blas_openblash1522bff_0     conda-forge [blas_openblas] --> 1.3.2-py36h921218d_0  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     scikit-learn:  0.20.1-py36_blas_openblashebff5e3_1200 conda-forge [blas_openblas] --> 0.20.1-py36h22eb022_0
#
#
# Downloading and Extracting Packages
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# scikit-learn-0.20.1  | 5.7 MB    | ##################################### | 100%
# liblapack-3.8.0      | 10 KB     | ##################################### | 100%
# scipy-1.3.2          | 18.0 MB   | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# libopenblas-0.3.6    | 7.7 MB    | ##################################### | 100%
# liblapacke-3.8.0     | 10 KB     | ##################################### | 100%
# numpy-1.17.3         | 5.2 MB    | ##################################### | 100%
# libcblas-3.8.0       | 10 KB     | ##################################### | 100%
# libblas-3.8.0        | 10 KB     | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# blas-2.11            | 10 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# # Yogyakarta Location and Maps

# %%
# Yogyakarta Indonesia Longitude and Latitude

address = 'Yogyakarta'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
lat = location.latitude
long = location.longitude
print(address + ' coordinates: {},{}.'.format(lat,long))
# Out:
# Yogyakarta coordinates: -7.8011945,110.364917.

# %%
map = folium.Map(location=[lat, long], zoom_start=15)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Foursquare API

# %%
CLIENT_ID = 'C1GZPKDDUHFF4ONSKUWUZJJVHJMW5JCYMXN2HUEK2HKJODLM' # your Foursquare ID
CLIENT_SECRET = 'PCSYFGSY1CQ4CVYWMMXJSDRYEFTORMTDCVT2IRV4DJM3HXKA' # your Foursquare Secret
VERSION = '20180605'
LIMIT = 100
radius = 500

# %%
url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    lat, 
    long, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?&client_id=C1GZPKDDUHFF4ONSKUWUZJJVHJMW5JCYMXN2HUEK2HKJODLM&client_secret=PCSYFGSY1CQ4CVYWMMXJSDRYEFTORMTDCVT2IRV4DJM3HXKA&v=20180605&ll=-7.8011945,110.364917&radius=500&limit=100'

# %% [markdown]
# # Check for Bakpia location in Yogyakarta

# %%
search_query = 'bakpia'
radius = 800
print(search_query + ' .... OK!')
# Out:
# bakpia .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, long, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=C1GZPKDDUHFF4ONSKUWUZJJVHJMW5JCYMXN2HUEK2HKJODLM&client_secret=PCSYFGSY1CQ4CVYWMMXJSDRYEFTORMTDCVT2IRV4DJM3HXKA&ll=-7.8011945,110.364917&v=20180605&query=bakpia&radius=800&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5de79e7347b43d4c24255d45'},
#  'response': {'venues': [{'id': '4d8c5649ac798cfad84629e4',
#     'name': 'Bakpia Pathok 25',
#     'location': {'address': 'Jl. AIP II KS Tubun No. 65',
#      'crossStreet': 'Ngampilan',
#      'lat': -7.79753955456098,
#      'lng': 110.36126322017809,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.79753955456098,
#        'lng': 110.36126322017809}],
#      'distance': 572,
#      'postalCode': '55261',
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. AIP II KS Tubun No. 65 (Ngampilan)',
#       'Yogyakarta',
#       'DI Yogyakarta 55261',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4c31569c3896e21e3af7e690',
#     'name': 'Bakpia Patuk 75',
#     'location': {'address': 'Jl. AIP II K.S.Tubun No. 75',
#      'lat': -7.797516414237404,
#      'lng': 110.35781073215512,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.797516414237404,
#        'lng': 110.35781073215512}],
#      'distance': 884,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. AIP II K.S.Tubun No. 75',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4df6109f18a88611c6c537a9',
#     'name': 'Bakpia Pia Djogdja',
#     'location': {'address': 'Jl. Dagen no.7',
#      'lat': -7.793919831082295,
#      'lng': 110.36472596364057,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.793919831082295,
#        'lng': 110.36472596364057}],
#      'distance': 810,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. Dagen no.7',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4d12c2a4f58560fcb53c6bc2',
#     'name': 'Bakpia & Pia Djogdja Ibu Rasuna',
#     'location': {'address': 'Jl. Mataram',
#      'lat': -7.794259471464756,
#      'lng': 110.36784690403371,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.794259471464756,
#        'lng': 110.36784690403371}],
#      'distance': 836,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. Mataram',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4ed605dc6da1113502c6bf8a',
#     'name': 'Bakpia pathuk 99',
#     'location': {'address': 'Malioboro',
#      'lat': -7.8051578276111275,
#      'lng': 110.36040709844883,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.8051578276111275,
#        'lng': 110.36040709844883}],
#      'distance': 664,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Malioboro', 'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '5955e35835dfa7647d343622',
#     'name': 'Bakpia Kurniasari',
#     'location': {'lat': -7.8017791,
#      'lng': 110.3638352,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.8017791,
#        'lng': 110.3638352}],
#      'distance': 135,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '534ce547498eebf880694d14',
#     'name': 'Bakpia Raminten',
#     'location': {'address': 'Jl. K. H. Ahmad Dahlan No. 8',
#      'lat': -7.801345122637392,
#      'lng': 110.36311667909001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.801345122637392,
#        'lng': 110.36311667909001}],
#      'distance': 199,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. K. H. Ahmad Dahlan No. 8',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'shortName': 'Gift Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4c8f3e9c4e95236adb5682ca',
#     'name': 'Pusat Pembuatan Bakpia Pathok 25',
#     'location': {'address': 'Jl. Bhayangkara',
#      'lat': -7.796763755692988,
#      'lng': 110.3579774235515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.796763755692988,
#        'lng': 110.3579774235515}],
#      'distance': 910,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. Bhayangkara',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '520ae17f11d28380da00c631',
#     'name': 'Bakpia Pathok Vista',
#     'location': {'lat': -7.798791287064804,
#      'lng': 110.3642163232121,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.798791287064804,
#        'lng': 110.3642163232121}],
#      'distance': 278,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '537e2b85498e0a200b4c4771',
#     'name': 'bakpia song djie factory',
#     'location': {'address': 'Jl.bener No.7',
#      'crossStreet': 'Tegalrejo',
#      'lat': -7.798673152923584,
#      'lng': 110.36486053466797,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.798673152923584,
#        'lng': 110.36486053466797}],
#      'distance': 280,
#      'postalCode': '55241',
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl.bener No.7 (Tegalrejo)',
#       'Yogyakarta',
#       'DI Yogyakarta 55241',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '55d431ca498e2f359c121a06',
#     'name': 'Bakpia Citra Premium',
#     'location': {'address': 'Jl. Mataram No. 21',
#      'lat': -7.793617907893525,
#      'lng': 110.36802145156526,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.793617907893525,
#        'lng': 110.36802145156526}],
#      'distance': 910,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. Mataram No. 21',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '57235d18498efc35a2a585af',
#     'name': 'Bakpia Pathok 25',
#     'location': {'lat': -7.8034245,
#      'lng': 110.3630904,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.8034245,
#        'lng': 110.3630904}],
#      'distance': 319,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4f6d54d3e4b0e428423aab3b',
#     'name': 'Bakpia Patuk BuSri8',
#     'location': {'address': 'Jl. KS. Tubun No. 4',
#      'lat': -7.797601697913339,
#      'lng': 110.36139448788535,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.797601697913339,
#        'lng': 110.36139448788535}],
#      'distance': 557,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. KS. Tubun No. 4',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '5d2889500f3dbe0023c9aa50',
#     'name': 'Bakpia Juwara Satoe',
#     'location': {'lat': -7.795991,
#      'lng': 110.36207,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.795991,
#        'lng': 110.36207}],
#      'distance': 658,
#      'postalCode': '55272',
#      'cc': 'ID',
#      'city': 'Ngampilan',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Ngampilan', 'DI Yogyakarta 55272', 'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '50cbf550e4b0c490bb77ba81',
#     'name': 'Bakpia Bu Sri',
#     'location': {'address': 'Jl KS Tubun',
#      'lat': -7.798530274753928,
#      'lng': 110.3621217641647,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.798530274753928,
#        'lng': 110.3621217641647}],
#      'distance': 427,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl KS Tubun',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d179941735',
#       'name': 'Bagel Shop',
#       'pluralName': 'Bagel Shops',
#       'shortName': 'Bagels',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '5483749b498e6ba0cc78fe16',
#     'name': 'Bakpia Pathok 73b',
#     'location': {'lat': -7.79899787902832,
#      'lng': 110.36121368408203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.79899787902832,
#        'lng': 110.36121368408203}],
#      'distance': 476,
#      'cc': 'ID',
#      'city': 'Jogja',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jogja', 'Indonesia']},
#     'categories': [{'id': '4f2a210c4b9023bd5841ed28',
#       'name': 'Housing Development',
#       'pluralName': 'Housing Developments',
#       'shortName': 'Housing Development',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/housingdevelopment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '523938f611d25fd60a8f1477',
#     'name': 'bakpia pathok asli',
#     'location': {'lat': -7.80515897785,
#      'lng': 110.366699918,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.80515897785,
#        'lng': 110.366699918}],
#      'distance': 483,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '53121c5611d2285db13f5487',
#     'name': 'Bakpia Pathok Candi 22',
#     'location': {'address': 'Jogjakarta',
#      'crossStreet': 'Jl Jogo Negaran',
#      'lat': -7.795400619506836,
#      'lng': 110.36128234863281,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.795400619506836,
#        'lng': 110.36128234863281}],
#      'distance': 759,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jogjakarta (Jl Jogo Negaran)',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '52960eda3cf9994f4e043ac7',
#       'name': 'Javanese Restaurant',
#       'pluralName': 'Javanese Restaurants',
#       'shortName': 'Javanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indonesian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4fdabf00e4b05180f3b8ac30',
#     'name': 'Bakpia ayu center',
#     'location': {'lat': -7.79806,
#      'lng': 110.36172,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.79806,
#        'lng': 110.36172}],
#      'distance': 496,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '5212f20811d29a5a59aed13e',
#     'name': 'Bakpia Telo Ungu',
#     'location': {'lat': -7.79759798008852,
#      'lng': 110.36217412808004,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.79759798008852,
#        'lng': 110.36217412808004}],
#      'distance': 501,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4c95d04e94a0236a0cc29912',
#     'name': 'Bakpia Patuk 55',
#     'location': {'address': 'Jl. Sastrodipuran 11',
#      'lat': -7.797118895148604,
#      'lng': 110.36291304144052,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.797118895148604,
#        'lng': 110.36291304144052}],
#      'distance': 504,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. Sastrodipuran 11',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '52b10825498e992bc1c97160',
#     'name': 'Bakpia 55',
#     'location': {'address': 'Jalan Sastrodipuran 11',
#      'lat': -7.797004857398726,
#      'lng': 110.3629828600579,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.797004857398726,
#        'lng': 110.3629828600579}],
#      'distance': 512,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jalan Sastrodipuran 11',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4f7d6590e4b02e131414cdab',
#     'name': 'bakpia crispy putri & Bakpia 29',
#     'location': {'address': 'Gajah Mada 29',
#      'lat': -7.80137,
#      'lng': 110.36988,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.80137,
#        'lng': 110.36988}],
#      'distance': 547,
#      'postalCode': '55112',
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Gajah Mada 29',
#       'Yogyakarta',
#       'DI Yogyakarta 55112',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4c2c7b3d57a9c9b63671f767',
#     'name': 'bakpia busri',
#     'location': {'address': 'Jl. KS TUBUN NO.5',
#      'lat': -7.797544,
#      'lng': 110.361658,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.797544,
#        'lng': 110.361658}],
#      'distance': 542,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. KS TUBUN NO.5',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '574a8763498e3b6d1342ed41',
#     'name': 'Sentra Bakpia Pathok',
#     'location': {'lat': -7.8035602,
#      'lng': 110.3668141,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.8035602,
#        'lng': 110.3668141}],
#      'distance': 336,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4d56066c611aa35db9453c39',
#     'name': 'Bakpia Patuk Asli Bu Sri',
#     'location': {'address': 'Jl. Bayangkara No. 61',
#      'lat': -7.797042971414997,
#      'lng': 110.36210430952694,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.797042971414997,
#        'lng': 110.36210430952694}],
#      'distance': 556,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. Bayangkara No. 61',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d1bc941735',
#       'name': 'Cupcake Shop',
#       'pluralName': 'Cupcake Shops',
#       'shortName': 'Cupcakes',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '521495f011d2832c560fe52e',
#     'name': 'Bakpia Patok 25',
#     'location': {'address': 'Yogyakarta',
#      'crossStreet': 'Yogyakarta',
#      'lat': -7.796734707918432,
#      'lng': 110.36218395885619,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.796734707918432,
#        'lng': 110.36218395885619}],
#      'distance': 580,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Yogyakarta (Yogyakarta)',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d1f9941735',
#       'name': 'Food & Drink Shop',
#       'pluralName': 'Food & Drink Shops',
#       'shortName': 'Food & Drink',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '5128b031e4b089b21ad07bf7',
#     'name': 'Bakpia Pathuk 55',
#     'location': {'address': 'Jl. Bhayangkara 63',
#      'crossStreet': 'Ngampilan',
#      'lat': -7.797293186187744,
#      'lng': 110.36146545410156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.797293186187744,
#        'lng': 110.36146545410156}],
#      'distance': 577,
#      'postalCode': '55100',
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. Bhayangkara 63 (Ngampilan)',
#       'Yogyakarta',
#       'DI Yogyakarta 55100',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '55d1e9c9498e25647f6aeacb',
#     'name': 'Bakpia 694',
#     'location': {'lat': -7.7960987,
#      'lng': 110.3659424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.7960987,
#        'lng': 110.3659424}],
#      'distance': 578,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '51f8b9b5498e035ff5e20285',
#     'name': 'bakpiapia bakpia blasteran janggutnaga single ampyang kepyar',
#     'location': {'address': 'jl. mataram depan toko popeye music',
#      'crossStreet': 'jl. mataram jogja',
#      'lat': -7.7939414371597415,
#      'lng': 110.36770144778379,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.7939414371597415,
#        'lng': 110.36770144778379}],
#      'distance': 863,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['jl. mataram depan toko popeye music (jl. mataram jogja)',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '5247cda2498e40fb804e64f0',
#     'name': 'Bakpia Pathok Ruly',
#     'location': {'lat': -7.799451,
#      'lng': 110.359919,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.799451,
#        'lng': 110.359919}],
#      'distance': 584,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Yogyakarta', 'DI Yogyakarta', 'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4e4b621ba8097d9c84bb2fc7',
#     'name': 'Bakpia Lestari',
#     'location': {'address': 'Jl. KS Tubun 9 Pathuk',
#      'lat': -7.797558,
#      'lng': 110.360767,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.797558,
#        'lng': 110.360767}],
#      'distance': 611,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. KS Tubun 9 Pathuk',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '5204f4af498ead683e1c4770',
#     'name': 'Bakpia Oh Bakpia',
#     'location': {'lat': -7.8024522,
#      'lng': 110.3702909,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.8024522,
#        'lng': 110.3702909}],
#      'distance': 608,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4d9ffa8fd3f0145607af4671',
#     'name': 'Bakpia Pathok 145 (Ibu Sri Astuti)',
#     'location': {'address': 'Jl. Kaliurang KM 5,6',
#      'lat': -7.797294560996653,
#      'lng': 110.36885928019709,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.797294560996653,
#        'lng': 110.36885928019709}],
#      'distance': 614,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. Kaliurang KM 5,6',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d1f9941735',
#       'name': 'Food & Drink Shop',
#       'pluralName': 'Food & Drink Shops',
#       'shortName': 'Food & Drink',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '527620e511d2f7102d56288c',
#     'name': 'Bakpia Ruly',
#     'location': {'lat': -7.79694,
#      'lng': 110.36141,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.79694,
#        'lng': 110.36141}],
#      'distance': 611,
#      'cc': 'ID',
#      'city': 'Jl. K.S Tubun No.65 D',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. K.S Tubun No.65 D',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '51d55bfa498e79475bc5bdee',
#     'name': 'Bakpia Puspita',
#     'location': {'lat': -7.7992243,
#      'lng': 110.3596766,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.7992243,
#        'lng': 110.3596766}],
#      'distance': 618,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '555d4d47498e9137b98f1b30',
#     'name': 'Bakpia Agi',
#     'location': {'lat': -7.796172360445801,
#      'lng': 110.3622439466387,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.796172360445801,
#        'lng': 110.3622439466387}],
#      'distance': 632,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4c924fe04c19ef3b5a3c8ce1',
#     'name': 'bakpia vista',
#     'location': {'address': 'jalan jogonegaran',
#      'lat': -7.7966754191650525,
#      'lng': 110.36157131195068,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.7966754191650525,
#        'lng': 110.36157131195068}],
#      'distance': 623,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['jalan jogonegaran',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '5090cae6e4b014dc94762206',
#     'name': 'Bakpia yessica',
#     'location': {'address': 'Porwodiningratan NG1/734',
#      'crossStreet': 'Pathuk',
#      'lat': -7.80278,
#      'lng': 110.35937,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.80278,
#        'lng': 110.35937}],
#      'distance': 636,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Porwodiningratan NG1/734 (Pathuk)',
#       'Yogyakarta',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '578b5e21498efcb222cb6f8b',
#     'name': 'Bakpia Pathok Mayang 757',
#     'location': {'lat': -7.796157,
#      'lng': 110.362022,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.796157,
#        'lng': 110.362022}],
#      'distance': 645,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '5204f461498e1bf7d73dc7ae',
#     'name': 'Bakpia 25 tpi Hrganya 30',
#     'location': {'lat': -7.8065675,
#      'lng': 110.3677071,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.8065675,
#        'lng': 110.3677071}],
#      'distance': 672,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '51cc0246498e656466cefc0d',
#     'name': 'Bakpia pathuk 882',
#     'location': {'address': 'Prawirodirjan',
#      'crossStreet': 'Jogja',
#      'lat': -7.804187600000001,
#      'lng': 110.3703517,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.804187600000001,
#        'lng': 110.3703517}],
#      'distance': 685,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Prawirodirjan (Jogja)', 'Indonesia']},
#     'categories': [{'id': '4deefc054765f83613cdba6f',
#       'name': 'Indonesian Restaurant',
#       'pluralName': 'Indonesian Restaurants',
#       'shortName': 'Indonesian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indonesian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '52ec5e92498ef50fbab4ca56',
#     'name': 'Bakpia Telo Ungu',
#     'location': {'lat': -7.806338793470693,
#      'lng': 110.36848691181812,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.806338793470693,
#        'lng': 110.36848691181812}],
#      'distance': 694,
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Yogyakarta', 'DI Yogyakarta', 'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '51c12318498eadedbbd37df0',
#     'name': 'Bakpia Patuk 75',
#     'location': {'lat': -7.801,
#      'lng': 110.35827,
#      'labeledLatLngs': [{'label': 'display', 'lat': -7.801, 'lng': 110.35827}],
#      'distance': 733,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '5443512e498e1a99f72acc6b',
#     'name': 'Bakpia 20',
#     'location': {'lat': -7.7977888,
#      'lng': 110.3591669,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.7977888,
#        'lng': 110.3591669}],
#      'distance': 738,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '50920b87e4b07ca5e4da8549',
#     'name': 'Bakpia Pathuk 526 Sedulur',
#     'location': {'address': 'Sanggrahan Pathuk Ng1/526 Yk',
#      'crossStreet': 'Jl.ks.tubun',
#      'lat': -7.797133922576904,
#      'lng': 110.35951232910156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.797133922576904,
#        'lng': 110.35951232910156}],
#      'distance': 748,
#      'postalCode': '55261',
#      'cc': 'ID',
#      'city': 'Yogyakarta',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Sanggrahan Pathuk Ng1/526 Yk (Jl.ks.tubun)',
#       'Yogyakarta',
#       'DI Yogyakarta 55261',
#       'Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '58f19989a8792166c429a345',
#     'name': 'Bakpia Patuk 731 Dewa',
#     'location': {'lat': -7.797886,
#      'lng': 110.358974,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.797886,
#        'lng': 110.358974}],
#      'distance': 751,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '4c8b884a1eafb1f724518435',
#     'name': 'Pusat oleh-oleh bakpia 75',
#     'location': {'address': 'Jl. KS tubun no.83',
#      'lat': -7.796910009677441,
#      'lng': 110.36528687754003,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.796910009677441,
#        'lng': 110.36528687754003}],
#      'distance': 478,
#      'cc': 'ID',
#      'city': 'Jogja',
#      'state': 'DI Yogyakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. KS tubun no.83',
#       'Jogja',
#       'DI Yogyakarta',
#       'Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '56b883e9498e6f4be1d97a09',
#     'name': 'Bakpia Kurnia 747',
#     'location': {'lat': -7.7985057,
#      'lng': 110.3585722,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.7985057,
#        'lng': 110.3585722}],
#      'distance': 761,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [],
#     'referralId': 'v-1575460458',
#     'hasPerk': False},
#    {'id': '51c512a1498e778c0e1e40d7',
#     'name': 'Bakpia Pathok 25, Jl. Sidomukti',
#     'location': {'lat': -7.8067474365234375,
#      'lng': 110.3609390258789,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -7.8067474365234375,
#        'lng': 110.3609390258789}],
#      'distance': 758,
#      'cc': 'ID',
#      'country': 'Indonesia',
#      'formattedAddress': ['Indonesia']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575460458',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues=results['response']['venues'] 

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                             name  \
# 0  4d8c5649ac798cfad84629e4                 Bakpia Pathok 25
# 1  4c31569c3896e21e3af7e690                  Bakpia Patuk 75
# 2  4df6109f18a88611c6c537a9               Bakpia Pia Djogdja
# 3  4d12c2a4f58560fcb53c6bc2  Bakpia & Pia Djogdja Ibu Rasuna
# 4  4ed605dc6da1113502c6bf8a                 Bakpia pathuk 99
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1c7941735', 'name': 'S...  v-1575460458    False
# 1  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1575460458    False
# 2  [{'id': '4bf58dd8d48988d1c7941735', 'name': 'S...  v-1575460458    False
# 3  [{'id': '4bf58dd8d48988d1c7941735', 'name': 'S...  v-1575460458    False
# 4  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1575460458    False
#
#               location.address location.crossStreet  location.lat  \
# 0   Jl. AIP II KS Tubun No. 65            Ngampilan     -7.797540
# 1  Jl. AIP II K.S.Tubun No. 75                  NaN     -7.797516
# 2               Jl. Dagen no.7                  NaN     -7.793920
# 3                  Jl. Mataram                  NaN     -7.794259
# 4                    Malioboro                  NaN     -7.805158
#
#    location.lng                            location.labeledLatLngs  \
# 0    110.361263  [{'label': 'display', 'lat': -7.79753955456098...
# 1    110.357811  [{'label': 'display', 'lat': -7.79751641423740...
# 2    110.364726  [{'label': 'display', 'lat': -7.79391983108229...
# 3    110.367847  [{'label': 'display', 'lat': -7.79425947146475...
# 4    110.360407  [{'label': 'display', 'lat': -7.80515782761112...
#
#    location.distance location.postalCode location.cc location.city  \
# 0                572               55261          ID    Yogyakarta
# 1                884                 NaN          ID    Yogyakarta
# 2                810                 NaN          ID    Yogyakarta
# 3                836                 NaN          ID    Yogyakarta
# 4                664                 NaN          ID           NaN
#
#   location.state location.country  \
# 0  DI Yogyakarta        Indonesia
# 1  DI Yogyakarta        Indonesia
# 2  DI Yogyakarta        Indonesia
# 3  DI Yogyakarta        Indonesia
# 4            NaN        Indonesia
#
#                            location.formattedAddress
# 0  [Jl. AIP II KS Tubun No. 65 (Ngampilan), Yogya...
# 1  [Jl. AIP II K.S.Tubun No. 75, Yogyakarta, DI Y...
# 2  [Jl. Dagen no.7, Yogyakarta, DI Yogyakarta, In...
# 3  [Jl. Mataram, Yogyakarta, DI Yogyakarta, Indon...
# 4                             [Malioboro, Indonesia]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                               name   categories                      address  \
# 0                 Bakpia Pathok 25  Snack Place   Jl. AIP II KS Tubun No. 65
# 1                  Bakpia Patuk 75       Bakery  Jl. AIP II K.S.Tubun No. 75
# 2               Bakpia Pia Djogdja  Snack Place               Jl. Dagen no.7
# 3  Bakpia & Pia Djogdja Ibu Rasuna  Snack Place                  Jl. Mataram
# 4                 Bakpia pathuk 99       Bakery                    Malioboro
#
#   crossStreet       lat         lng  \
# 0   Ngampilan -7.797540  110.361263
# 1         NaN -7.797516  110.357811
# 2         NaN -7.793920  110.364726
# 3         NaN -7.794259  110.367847
# 4         NaN -7.805158  110.360407
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': -7.79753955456098...       572      55261  ID
# 1  [{'label': 'display', 'lat': -7.79751641423740...       884        NaN  ID
# 2  [{'label': 'display', 'lat': -7.79391983108229...       810        NaN  ID
# 3  [{'label': 'display', 'lat': -7.79425947146475...       836        NaN  ID
# 4  [{'label': 'display', 'lat': -7.80515782761112...       664        NaN  ID
#
#          city          state    country  \
# 0  Yogyakarta  DI Yogyakarta  Indonesia
# 1  Yogyakarta  DI Yogyakarta  Indonesia
# 2  Yogyakarta  DI Yogyakarta  Indonesia
# 3  Yogyakarta  DI Yogyakarta  Indonesia
# 4         NaN            NaN  Indonesia
#
#                                     formattedAddress                        id
# 0  [Jl. AIP II KS Tubun No. 65 (Ngampilan), Yogya...  4d8c5649ac798cfad84629e4
# 1  [Jl. AIP II K.S.Tubun No. 75, Yogyakarta, DI Y...  4c31569c3896e21e3af7e690
# 2  [Jl. Dagen no.7, Yogyakarta, DI Yogyakarta, In...  4df6109f18a88611c6c537a9
# 3  [Jl. Mataram, Yogyakarta, DI Yogyakarta, Indon...  4d12c2a4f58560fcb53c6bc2
# 4                             [Malioboro, Indonesia]  4ed605dc6da1113502c6bf8a

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                               name   categories                      address  \
# 0                 Bakpia Pathok 25  Snack Place   Jl. AIP II KS Tubun No. 65
# 1                  Bakpia Patuk 75       Bakery  Jl. AIP II K.S.Tubun No. 75
# 2               Bakpia Pia Djogdja  Snack Place               Jl. Dagen no.7
# 3  Bakpia & Pia Djogdja Ibu Rasuna  Snack Place                  Jl. Mataram
# 4                 Bakpia pathuk 99       Bakery                    Malioboro
#
#   crossStreet       lat         lng  \
# 0   Ngampilan -7.797540  110.361263
# 1         NaN -7.797516  110.357811
# 2         NaN -7.793920  110.364726
# 3         NaN -7.794259  110.367847
# 4         NaN -7.805158  110.360407
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': -7.79753955456098...       572      55261  ID
# 1  [{'label': 'display', 'lat': -7.79751641423740...       884        NaN  ID
# 2  [{'label': 'display', 'lat': -7.79391983108229...       810        NaN  ID
# 3  [{'label': 'display', 'lat': -7.79425947146475...       836        NaN  ID
# 4  [{'label': 'display', 'lat': -7.80515782761112...       664        NaN  ID
#
#          city          state    country  \
# 0  Yogyakarta  DI Yogyakarta  Indonesia
# 1  Yogyakarta  DI Yogyakarta  Indonesia
# 2  Yogyakarta  DI Yogyakarta  Indonesia
# 3  Yogyakarta  DI Yogyakarta  Indonesia
# 4         NaN            NaN  Indonesia
#
#                                     formattedAddress                        id
# 0  [Jl. AIP II KS Tubun No. 65 (Ngampilan), Yogya...  4d8c5649ac798cfad84629e4
# 1  [Jl. AIP II K.S.Tubun No. 75, Yogyakarta, DI Y...  4c31569c3896e21e3af7e690
# 2  [Jl. Dagen no.7, Yogyakarta, DI Yogyakarta, In...  4df6109f18a88611c6c537a9
# 3  [Jl. Mataram, Yogyakarta, DI Yogyakarta, Indon...  4d12c2a4f58560fcb53c6bc2
# 4                             [Malioboro, Indonesia]  4ed605dc6da1113502c6bf8a

# %%
dataframe_filtered.name
# Out:
# 0                                      Bakpia Pathok 25
# 1                                       Bakpia Patuk 75
# 2                                    Bakpia Pia Djogdja
# 3                       Bakpia & Pia Djogdja Ibu Rasuna
# 4                                      Bakpia pathuk 99
# 5                                     Bakpia Kurniasari
# 6                                       Bakpia Raminten
# 7                      Pusat Pembuatan Bakpia Pathok 25
# 8                                   Bakpia Pathok Vista
# 9                              bakpia song djie factory
# 10                                 Bakpia Citra Premium
# 11                                     Bakpia Pathok 25
# 12                                  Bakpia Patuk BuSri8
# 13                                  Bakpia Juwara Satoe
# 14                                        Bakpia Bu Sri
# 15                                    Bakpia Pathok 73b
# 16                                   bakpia pathok asli
# 17                               Bakpia Pathok Candi 22
# 18                                    Bakpia ayu center
# 19                                      Bakpia Patuk 55
# 20                                     Bakpia Telo Ungu
# 21                                            Bakpia 55
# 22                      bakpia crispy putri & Bakpia 29
# 23                                         bakpia busri
# 24                                 Sentra Bakpia Pathok
# 25                                      Bakpia Patok 25
# 26                             Bakpia Patuk Asli Bu Sri
# 27                                     Bakpia Pathuk 55
# 28                                           Bakpia 694
# 29    bakpiapia bakpia blasteran janggutnaga single ...
# 30                                   Bakpia Pathok Ruly
# 31                                       Bakpia Lestari
# 32                   Bakpia Pathok 145 (Ibu Sri Astuti)
# 33                                     Bakpia Oh Bakpia
# 34                                          Bakpia Ruly
# 35                                       Bakpia Puspita
# 36                                           Bakpia Agi
# 37                                       Bakpia yessica
# 38                                         bakpia vista
# 39                             Bakpia Pathok Mayang 757
# 40                             Bakpia 25 tpi Hrganya 30
# 41                                    Bakpia pathuk 882
# 42                                     Bakpia Telo Ungu
# 43                                      Bakpia Patuk 75
# 44                                            Bakpia 20
# 45                            Bakpia Pathuk 526 Sedulur
# 46                                Bakpia Patuk 731 Dewa
# 47                                    Bakpia Kurnia 747
# 48                      Bakpia Pathok 25, Jl. Sidomukti
# 49                            Pusat oleh-oleh bakpia 75
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[lat, long], zoom_start=20) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [lat, long],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Check for Trending Venues

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, lat, long, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5de79e3cdd0f854c382aa365'},
#  'response': {'venues': []}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)
        
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'

# %% [markdown]
# # Check for Review
# ## (Bakpia Pathuk 25 as an example)

# %%
venue_id = '4d8c5649ac798cfad84629e4' # Bakpia Pathuk 25 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4d8c5649ac798cfad84629e4?client_id=C1GZPKDDUHFF4ONSKUWUZJJVHJMW5JCYMXN2HUEK2HKJODLM&client_secret=PCSYFGSY1CQ4CVYWMMXJSDRYEFTORMTDCVT2IRV4DJM3HXKA&v=20180605'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4d8c5649ac798cfad84629e4',
#  'name': 'Bakpia Pathok 25',
#  'contact': {'phone': '+6283820085102', 'formattedPhone': '+62 838-2008-5102'},
#  'location': {'address': 'Jl. AIP II KS Tubun No. 65',
#   'crossStreet': 'Ngampilan',
#   'lat': -7.79753955456098,
#   'lng': 110.36126322017809,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': -7.79753955456098,
#     'lng': 110.36126322017809}],
#   'postalCode': '55261',
#   'cc': 'ID',
#   'city': 'Yogyakarta',
#   'state': 'DI Yogyakarta',
#   'country': 'Indonesia',
#   'formattedAddress': ['Jl. AIP II KS Tubun No. 65 (Ngampilan)',
#    'Yogyakarta',
#    'DI Yogyakarta 55261',
#    'Indonesia']},
#  'canonicalUrl': 'https://foursquare.com/v/bakpia-pathok-25/4d8c5649ac798cfad84629e4',
#  'categories': [{'id': '4bf58dd8d48988d1c7941735',
#    'name': 'Snack Place',
#    'pluralName': 'Snack Places',
#    'shortName': 'Snacks',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d1f9941735',
#    'name': 'Food & Drink Shop',
#    'pluralName': 'Food & Drink Shops',
#    'shortName': 'Food & Drink',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#     'suffix': '.png'}},
#   {'id': '4bf58dd8d48988d16a941735',
#    'name': 'Bakery',
#    'pluralName': 'Bakeries',
#    'shortName': 'Bakery',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#     'suffix': '.png'}}],
#  'verified': False,
#  'stats': {'tipCount': 131},
#  'url': 'http://bakpia25.com',
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'likes': {'count': 292,
#   'groups': [{'type': 'others', 'count': 292, 'items': []}],
#   'summary': '292 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 7.9,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 428,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 445,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 445,
#     'items': [{'id': '5dd888f91d4eab000822dd5c',
#       'createdAt': 1574471929,
#       'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/18164731_EdjcAOlnwsdHFw9sX0mKwX4GISq0Wq0XvFLPOHy4TzI.jpg',
#       'width': 1440,
#       'height': 1920,
#       'user': {'id': '18164731',
#        'firstName': 'TEE',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/18164731-MP1YULIYCFC3WRB2.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1301042761,
#  'tips': {'count': 131,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 131,
#     'items': [{'id': '4c5c005e7735c9b65dfa8a72',
#       'createdAt': 1281097822,
#       'text': 'enak ih bakpia nya!!!!',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4c5c005e7735c9b65dfa8a72',
#       'lang': 'id',
#       'likes': {'count': 9,
#        'groups': [{'type': 'others',
#          'count': 9,
#          'items': [{'id': '11622008',
#            'firstName': 'FataRhan',
#            'lastName': 'Rifa Ria',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/TCBU0R3IVQH2LSVW.jpg'}},
#           {'id': '43588823',
#            'firstName': 'Iwan',
#            'lastName': 'Winardi',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/blank_boy.png',
#             'default': True}},
#           {'id': '2628630',
#            'firstName': 'Amelinda',
#            'lastName': 'Memey',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/3KH4OUKS5NUVCSZA.jpg'}},
#           {'id': '37322145',
#            'firstName': 'Putra',
#            'lastName': 'Bagus',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/37322145-O1HOS3XFSBL3QAAD.jpg'}}]}],
#        'summary': '9 likes'},
#       'logView': True,
#       'agreeCount': 4,
#       'disagreeCount': 0,
#       'todo': {'count': 1},
#       'user': {'id': '1694862',
#        'firstName': 'Natisya Fauzia',
#        'lastName': 'Marizkita',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/RCYLZXILVHPV05GE.jpg'}}}]}]},
#  'shortUrl': 'http://4sq.com/gtaXWA',
#  'timeZone': 'Asia/Jakarta',
#  'listed': {'count': 55,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 55,
#     'items': [{'id': '4e5184ecc65bb313baa37769',
#       'name': 'Yogjakarta, Never Ending Asia #4sqCities',
#       'description': 'Yogyakarta, is one of famous International tourist destinations in Java – Indonesia. A unique combination of history, traditions,and culture make Yogyakarta a very worthwhile place to visit.',
#       'type': 'others',
#       'user': {'id': '6115895',
#        'firstName': 'JOEWANA',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/0MJTJLOZ4VE0PWDV.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/joewana1/list/yogjakarta-never-ending-asia-4sqcities',
#       'canonicalUrl': 'https://foursquare.com/joewana1/list/yogjakarta-never-ending-asia-4sqcities',
#       'createdAt': 1313965292,
#       'updatedAt': 1410785123,
#       'photo': {'id': '4f79e237e4b0e6832b13b70b',
#        'createdAt': 1333387831,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/7kDeFgBTErS7QFpapqI1DlJQZNDM4r1M-V-JDwT5QMo.gif',
#        'width': 279,
#        'height': 208,
#        'user': {'id': '6115895',
#         'firstName': 'JOEWANA',
#         'gender': 'male',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/0MJTJLOZ4VE0PWDV.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 341},
#       'listItems': {'count': 65,
#        'items': [{'id': 't4f7dfc50e4b07071b5ee1a2b',
#          'createdAt': 1333656059,
#          'photo': {'id': '4f49e466e4b007d39032fc22',
#           'createdAt': 1330242662,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/3bYAHw_28p2Pw8nqUGYWMW3kN5-8MZYKfrrB54watYo.jpg',
#           'width': 720,
#           'height': 540,
#           'user': {'id': '3418902',
#            'firstName': 'oka',
#            'lastName': 'mahardika',
#            'gender': 'none',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/YHIGUNCTRC124MQD.jpg'}},
#           'visibility': 'public'}}]}},
#      {'id': '4f0f202de4b08ead5f8e499b',
#       'name': 'Jogja Never Ending Asia',
#       'description': 'Yogyakarta is always Istimewa.\nwww.dedotphotography.com',
#       'entities': [{'indices': [31, 55],
#         'type': 'url',
#         'object': {'url': 'http://www.dedotphotography.com'}}],
#       'type': 'others',
#       'user': {'id': '1403883',
#        'firstName': 'Dedot',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/1403883_olcm8Roh_issTSQikOC2fnNrKfArqMLieUQ5Ik-5DeZ24fg2BRRMeXPIUQw-_5GH6AwHMQLsm.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/dedoth/list/jogja-never-ending-asia',
#       'canonicalUrl': 'https://foursquare.com/dedoth/list/jogja-never-ending-asia',
#       'createdAt': 1326391341,
#       'updatedAt': 1507921857,
#       'photo': {'id': '4fd97e59e4b01e3bc4c41d2c',
#        'createdAt': 1339653721,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/ev0vcNMlhADaVWmRKzhmYkuTblpYgpNG4UA3KBjqlnc.jpg',
#        'width': 460,
#        'height': 345,
#        'user': {'id': '3884877',
#         'firstName': 'Arifin',
#         'lastName': 'Satrio',
#         'gender': 'male',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/3884877-Y0YQWHCK2HMIZGSJ.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 10},
#       'listItems': {'count': 56,
#        'items': [{'id': 'v4d8c5649ac798cfad84629e4',
#          'createdAt': 1507736074}]}},
#      {'id': '515fd42fe4b035abd1adf84d',
#       'name': 'Daerah Istimewa Yogyakarta. Indonesia',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '7986294',
#        'firstName': 'Sawung',
#        'lastName': 'Galing',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/HWLKMQ2NUI5OY235.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/7986294/list/daerah-istimewa-yogyakarta-indonesia',
#       'canonicalUrl': 'https://foursquare.com/user/7986294/list/daerah-istimewa-yogyakarta-indonesia',
#       'createdAt': 1365234735,
#       'updatedAt': 1435292480,
#       'photo': {'id': '51667140b0edd46b493cde8c',
#        'createdAt': 1365668160,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/7986294_h6AdPKQN4EUNLnaqt7AYLwk1I6r0KeKn63e0-BAhZ-o.jpg',
#        'width': 960,
#        'height': 639,
#        'user': {'id': '7986294',
#         'firstName': 'Sawung',
#         'lastName': 'Galing',
#         'gender': 'male',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/HWLKMQ2NUI5OY235.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 31},
#       'listItems': {'count': 163,
#        'items': [{'id': 'v4d8c5649ac798cfad84629e4',
#          'createdAt': 1365252414,
#          'photo': {'id': '4e65a60445ddda352af214d2',
#           'createdAt': 1315284484,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/YWEPPNZKKYLTCQQCLJRQXHQQ44BB30QI1Q1ZGNTPZQYBHNBT.jpg',
#           'width': 720,
#           'height': 540,
#           'user': {'id': '1394312',
#            'firstName': 'Rezza',
#            'lastName': 'Habibie',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/FRAVDLD2RXF3Z3VT.jpg'}},
#           'visibility': 'public'}}]}},
#      {'id': '4faf3e2ce4b0fd09a976ac95',
#       'name': 'Food',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '10138821',
#        'firstName': 'Tiara',
#        'lastName': 'Sari Dewi',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/SLIUPE0ZAH2BJK1O.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/tsrdw/list/food',
#       'canonicalUrl': 'https://foursquare.com/tsrdw/list/food',
#       'createdAt': 1336884780,
#       'updatedAt': 1391631327,
#       'followers': {'count': 10},
#       'listItems': {'count': 62,
#        'items': [{'id': 'v4d8c5649ac798cfad84629e4',
#          'createdAt': 1337041463}]}}]}]},
#  'popular': {'status': 'Likely open',
#   'richStatus': {'entities': [], 'text': 'Likely open'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '9:00 AM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Thu–Fri',
#     'open': [{'renderedTime': '9:00 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '9:00 AM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '8:00 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '9:00 AM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '1:00 PM–2:00 PM'},
#      {'renderedTime': '4:00 PM–8:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 5,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Dinner, Breakfast & more',
#     'count': 8,
#     'items': [{'displayName': 'Breakfast', 'displayValue': 'Breakfast'},
#      {'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'}]}]},
#  'bestPhoto': {'id': '5dd888f91d4eab000822dd5c',
#   'createdAt': 1574471929,
#   'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/18164731_EdjcAOlnwsdHFw9sX0mKwX4GISq0Wq0XvFLPOHy4TzI.jpg',
#   'width': 1440,
#   'height': 1920,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '5dd888f91d4eab000822dd5c',
#    'value': -15720432},
#   'highlightTextColor': {'photoId': '5dd888f91d4eab000822dd5c', 'value': -1},
#   'algoVersion': 3}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.9

# %%
result['response']['venue']['tips']['count']
# Out:
# 131

# %% [markdown]
# # Checking for Tips and Review from other Users

# %%
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5de79ef960ba08001b9fb410'},
#  'response': {'tips': {'count': 131,
#    'items': [{'id': '50ddaaa3e4b0b8da1c30b572',
#      'createdAt': 1356704419,
#      'text': 'Bakpia pathok 25 salah satu bakpia yg terkenal di yogyakarta, dgn harga RP 25 rb anda bisa dapet 1 kotak bakpia yg masih hangat.. lokasinya strategis atau anda bisa minta aner tukang becak ke sana...',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/50ddaaa3e4b0b8da1c30b572',
#      'lang': 'id',
#      'likes': {'count': 1,
#       'groups': [{'type': 'others',
#         'count': 1,
#         'items': [{'id': '2628630',
#           'firstName': 'Amelinda',
#           'lastName': 'Memey',
#           'gender': 'female',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/3KH4OUKS5NUVCSZA.jpg'}}]}],
#       'summary': '1 like'},
#      'logView': True,
#      'agreeCount': 4,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '11542398',
#       'firstName': 'aprizal ramadhan',
#       'gender': 'male',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/11542398-0UN3LZ4KJE4IJM4Y.jpg'}}}]}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                                                                                                                                                                                       text  \
# 0  Bakpia pathok 25 salah satu bakpia yg terkenal di yogyakarta, dgn harga RP 25 rb anda bisa dapet 1 kotak bakpia yg masih hangat.. lokasinya strategis atau anda bisa minta aner tukang becak ke sana...
#
#    agreeCount  disagreeCount                        id    user.firstName  \
# 0  4           0              50ddaaa3e4b0b8da1c30b572  aprizal ramadhan
#
#    user.lastName user.gender   user.id
# 0 NaN             male        11542398

# %% [markdown]
# Translation: *Bakpia Pathok 25* (One of the Bakpia Brand), is very famous in Yogyakarta, with the price of IDR25k, you can get one freshly baked Bakpia. The location is strategic, you can reach it by rickshaw.
